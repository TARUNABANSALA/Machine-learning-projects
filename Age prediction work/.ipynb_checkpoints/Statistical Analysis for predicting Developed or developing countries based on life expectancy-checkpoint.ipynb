# %% [markdown]
# # Statistical Analysis on factors influencing Life Expectancy
# Using the WHO life expectancy dataset
# Inspiration
# The data-set aims to answer the following key questions:
# Does various predicting factors which has been chosen initially really affect the Life expectancy? What are the predicting variables actually affecting the life expectancy?
# Should a country having a lower life expectancy value(<65) increase its healthcare expenditure in order to improve its average lifespan?
# What is the impact of schooling on the lifespan of humans?
# Do densely populated countries tend to have lower life expectancy?

# %%
# !pip install --upgrade tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\panka\anaconda3\lib\site-packages (2.13.0)
# Requirement already satisfied: tensorflow-intel==2.13.0 in c:\users\panka\anaconda3\lib\site-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\panka\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.31.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in c:\users\panka\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.13.0)
# Requirement already satisfied: packaging in c:\users\panka\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (23.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\panka\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (4.23.4)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\panka\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.4.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\panka\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.4.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in c:\users\panka\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.13.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\panka\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.6.3)
# Requirement already satisfied: keras<2.14,>=2.13.1 in c:\users\panka\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.13.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\panka\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.56.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\panka\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.2.0)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in c:\users\panka\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.24.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\panka\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.16.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\panka\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.14.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\panka\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (16.0.6)
# Requirement already satisfied: setuptools in c:\users\panka\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (66.0.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in c:\users\panka\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (4.5.0)
# Requirement already satisfied: flatbuffers>=23.1.21 in c:\users\panka\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (23.5.26)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\panka\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (3.7.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\panka\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (3.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\panka\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\panka\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.13.0->tensorflow) (0.38.4)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\panka\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.0.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\panka\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.7.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\panka\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.28.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\panka\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (1.0.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\panka\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.22.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\panka\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\panka\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\panka\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.2.8)
# Requirement already satisfied: urllib3<2.0 in c:\users\panka\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (1.26.15)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\panka\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (5.3.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\panka\anaconda3\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\panka\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (6.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\panka\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\panka\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\panka\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.0.4)
# Requirement already satisfied: zipp>=0.5 in c:\users\panka\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\panka\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\panka\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.2.2)

# %%
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import ModelCheckpoint
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# %%
# Read the CSV file from the Resources folder into a Pandas DataFrame
data = 'life_expectancy_data.csv'
dataframe = pd.read_csv(data)

# Review the DataFrame
dataframe.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0    6.0               8.16         65.0        0.1  584.259210  33736494.0
# 1   58.0               8.18         62.0        0.1  612.696514    327582.0
# 2   62.0               8.13         64.0        0.1  631.744976  31731688.0
# 3   67.0               8.52         67.0        0.1  669.959000   3696958.0
# 4   68.0               7.87         68.0        0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
#
# [5 rows x 22 columns]

# %%
dataframe.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# min       0.010000                0.000000     1.000000       0.000000
# 25%       0.877500                4.685343    77.000000       0.000000
# 50%       3.755000               64.912906    92.000000      17.000000
# 75%       7.702500              441.534144    97.000000     360.250000
# max      17.870000            19479.911610    99.000000  212183.000000
#
#               BMI   under-five deaths         Polio  Total expenditure  \
# count  2904.000000         2938.000000  2919.000000         2712.00000
# mean     38.321247           42.035739    82.550188            5.93819
# std      20.044034          160.445548    23.428046            2.49832
# min       1.000000            0.000000     3.000000            0.37000
# 25%      19.300000            0.000000    78.000000            4.26000
# 50%      43.500000            4.000000    93.000000            5.75500
# 75%      56.200000           28.000000    97.000000            7.49250
# max      87.300000         2500.000000    99.000000           17.60000
#
#        Diphtheria      HIV/AIDS            GDP    Population  \
# count  2919.000000  2938.000000    2490.000000  2.286000e+03
# mean     82.324084     1.742103    7483.158469  1.275338e+07
# std      23.716912     5.077785   14270.169342  6.101210e+07
# min       2.000000     0.100000       1.681350  3.400000e+01
# 25%      78.000000     0.100000     463.935626  1.957932e+05
# 50%      93.000000     0.100000    1766.947595  1.386542e+06
# 75%      97.000000     0.800000    5910.806335  7.420359e+06
# max      99.000000    50.600000  119172.741800  1.293859e+09
#
#         thinness  1-19 years   thinness 5-9 years  \
# count            2904.000000          2904.000000
# mean                4.839704             4.870317
# std                 4.420195             4.508882
# min                 0.100000             0.100000
# 25%                 1.600000             1.500000
# 50%                 3.300000             3.300000
# 75%                 7.200000             7.200000
# max                27.700000            28.600000
#
#        Income composition of resources    Schooling
# count                      2771.000000  2775.000000
# mean                          0.627551    11.992793
# std                           0.210904     3.358920
# min                           0.000000     0.000000
# 25%                           0.493000    10.100000
# 50%                           0.677000    12.300000
# 75%                           0.779000    14.300000
# max                           0.948000    20.700000

# %% [markdown]
# ## Cleaning the data
# Some cell names have trailing spaces or are composed of two separate names, I am gonna fix that and impose a more consistent naming scheme

# %%
# Renaming some column names as they contain trailing spaces.
dataframe.rename(columns={" BMI ":"BMI","Life expectancy ":"Life_Expectancy","Adult Mortality":"Adult_Mortality",
                   "infant deaths":"Infant_Deaths","percentage expenditure":"Percentage_Exp","Hepatitis B":"HepatitisB",
                  "Measles ":"Measles"," BMI ":"BMI","under-five deaths ":"Under_Five_Deaths","Diphtheria ":"Diphtheria",
                  " HIV/AIDS":"HIV/AIDS"," thinness  1-19 years":"thinness_1to19_years"," thinness 5-9 years":"thinness_5to9_years","Income composition of resources":"Income_Comp_Of_Resources",
                   "Total expenditure":"Tot_Exp"},inplace=True)
dataframe.head()
# Out:
#        Country  Year      Status  Life_Expectancy  Adult_Mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    Infant_Deaths  Alcohol  Percentage_Exp  HepatitisB  Measles  ...  Polio  \
# 0             62     0.01       71.279624        65.0     1154  ...    6.0
# 1             64     0.01       73.523582        62.0      492  ...   58.0
# 2             66     0.01       73.219243        64.0      430  ...   62.0
# 3             69     0.01       78.184215        67.0     2787  ...   67.0
# 4             71     0.01        7.097109        68.0     3013  ...   68.0
#
#    Tot_Exp  Diphtheria  HIV/AIDS         GDP  Population  \
# 0     8.16        65.0       0.1  584.259210  33736494.0
# 1     8.18        62.0       0.1  612.696514    327582.0
# 2     8.13        64.0       0.1  631.744976  31731688.0
# 3     8.52        67.0       0.1  669.959000   3696958.0
# 4     7.87        68.0       0.1   63.537231   2978599.0
#
#    thinness_1to19_years  thinness_5to9_years  Income_Comp_Of_Resources  \
# 0                  17.2                 17.3                     0.479
# 1                  17.5                 17.5                     0.476
# 2                  17.7                 17.7                     0.470
# 3                  17.9                 18.0                     0.463
# 4                  18.2                 18.2                     0.454
#
#    Schooling
# 0       10.1
# 1       10.0
# 2        9.9
# 3        9.8
# 4        9.5
#
# [5 rows x 22 columns]

# %%
# Verifying whether data for each variable is according to its dataype or not.
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Country                   2938 non-null   object
#  1   Year                      2938 non-null   int64
#  2   Status                    2938 non-null   object
#  3   Life_Expectancy           2928 non-null   float64
#  4   Adult_Mortality           2928 non-null   float64
#  5   Infant_Deaths             2938 non-null   int64
#  6   Alcohol                   2744 non-null   float64
#  7   Percentage_Exp            2938 non-null   float64
#  8   HepatitisB                2385 non-null   float64
#  9   Measles                   2938 non-null   int64
#  10  BMI                       2904 non-null   float64
#  11  Under_Five_Deaths         2938 non-null   int64
#  12  Polio                     2919 non-null   float64
#  13  Tot_Exp                   2712 non-null   float64
#  14  Diphtheria                2919 non-null   float64
#  15  HIV/AIDS                  2938 non-null   float64
#  16  GDP                       2490 non-null   float64
#  17  Population                2286 non-null   float64
#  18  thinness_1to19_years      2904 non-null   float64
#  19  thinness_5to9_years       2904 non-null   float64
#  20  Income_Comp_Of_Resources  2771 non-null   float64
#  21  Schooling                 2775 non-null   float64
# dtypes: float64(16), int64(4), object(2)
# memory usage: 505.1+ KB

# %%
# Identify percentage of null values in each column.
dataframe.isnull().sum()*100/dataframe.isnull().count()
# Out:
# Country                      0.000000
# Year                         0.000000
# Status                       0.000000
# Life_Expectancy              0.340368
# Adult_Mortality              0.340368
# Infant_Deaths                0.000000
# Alcohol                      6.603131
# Percentage_Exp               0.000000
# HepatitisB                  18.822328
# Measles                      0.000000
# BMI                          1.157250
# Under_Five_Deaths            0.000000
# Polio                        0.646698
# Tot_Exp                      7.692308
# Diphtheria                   0.646698
# HIV/AIDS                     0.000000
# GDP                         15.248468
# Population                  22.191967
# thinness_1to19_years         1.157250
# thinness_5to9_years          1.157250
# Income_Comp_Of_Resources     5.684139
# Schooling                    5.547992
# dtype: float64

# %% [markdown]
# Creating country_list: A list called country_list is generated by extracting the unique values from the "Country" column. This list will contain the names of all countries present in the DataFrame.
# Creating fill_list: Another list named fill_list is created. It contains the names of columns that have missing values and need to be filled using interpolation. Interpolation is a method to estimate missing values based on the values of neighboring data points.
# Interpolation: The code uses a loop to perform interpolation for each country separately. For each country, it selects rows belonging to that country using dataframe.loc[dataframe['Country'] == country, fill_list]. The interpolate() method is then applied to those selected rows for the columns listed in fill_list. This will fill in missing values with interpolated values based on neighboring data points for each country.

# %%
# save the countries in a list
country_list = dataframe.Country.unique()

# list containing incomplete columns
fill_list = ['Life_Expectancy','Adult_Mortality','Alcohol','HepatitisB','BMI','Polio','Tot_Exp','Diphtheria','GDP','Population','thinness_1to19_years','thinness_5to9_years','Income_Comp_Of_Resources','Schooling']

# %% [markdown]
# The reason for using iloc twice in this line is to perform interpolation only on the specific subset of the DataFrame corresponding to the current country. By doing this within a loop for each country separately, the code ensures that interpolation is performed independently for each country, maintaining the temporal continuity of the data for individual countries without interpolating across different countries. This approach prevents any potential leakage of information between different countries and helps ensure that the interpolation is performed on a per-country basis.

# %%
# Treat null values using interpolation.
for country in country_list:
    dataframe.loc[dataframe['Country'] == country,fill_list] = dataframe.loc[dataframe['Country'] == country,fill_list].interpolate()
    
# Drop remaining null values after interpolation.
dataframe.dropna(inplace=True)

# %%
# Verifying null-values after applying above methods.
dataframe.isnull().sum()
# Out:
# Country                     0
# Year                        0
# Status                      0
# Life_Expectancy             0
# Adult_Mortality             0
# Infant_Deaths               0
# Alcohol                     0
# Percentage_Exp              0
# HepatitisB                  0
# Measles                     0
# BMI                         0
# Under_Five_Deaths           0
# Polio                       0
# Tot_Exp                     0
# Diphtheria                  0
# HIV/AIDS                    0
# GDP                         0
# Population                  0
# thinness_1to19_years        0
# thinness_5to9_years         0
# Income_Comp_Of_Resources    0
# Schooling                   0
# dtype: int64

# %% [markdown]
# ## Data analysis
# We are gonna look for relevant correlations to decide which columns we will use to train our model<br>
# Let's start with some general statistics about our data

# %%
# Life_Expectancy w.r.t Year using bar plot.
plt.figure(figsize=(4,5))
plt.bar(dataframe.groupby('Status')['Status'].count().index,dataframe.groupby('Status')['Life_Expectancy'].mean(),color='blue',alpha=0.50)
plt.xlabel("Country Status",fontsize=12)
plt.ylabel("Avg Life_Expectancy",fontsize=12)
plt.title("Life_Expectancy w.r.t Country Development")
plt.show()

# %%
round(dataframe[['Status','Life_Expectancy']].groupby(['Status']).mean(),2)
# Out:
#             Life_Expectancy
# Status
# Developed             78.83
# Developing            66.16

# %%
# Life_Expectancy w.r.t Year using bar plot.
plt.figure(figsize=(7,5))
plt.bar(dataframe.groupby('Year')['Year'].count().index,dataframe.groupby('Year')['Life_Expectancy'].mean(),color='pink',alpha=0.65)
plt.xlabel("Year",fontsize=12)
plt.ylabel("Avg Life_Expectancy",fontsize=12)
plt.title("Life_Expectancy w.r.t Year")
plt.show()

# %% [markdown]
# So there is a definite difference between developed countries and the rest, but at least the life expectancy improves every year.
# Now let's try to figure out wich features affect life expectancy the most.

# %%
plt.figure(figsize=(7,5))
plt.title("LifeExpectancy w.r.t Income_Comp_Of_Resources")
plt.xlabel("Income",fontsize=12)
plt.ylabel("Life_Expectancy",fontsize=12)
plt.scatter(dataframe["Income_Comp_Of_Resources"], dataframe["Life_Expectancy"])

# %%
plt.figure(figsize=(7,5))
plt.title("LifeExpectancy w.r.t years spent in school")
plt.xlabel("Years of schooling",fontsize=12)
plt.ylabel("Life_Expectancy",fontsize=12)
plt.scatter(dataframe["Schooling"], dataframe["Life_Expectancy"])

# %%
plt.figure(figsize=(7,5))
plt.title("Income w.r.t years spent in school")
plt.xlabel("Years of schooling",fontsize=12)
plt.ylabel("Income",fontsize=12)
plt.scatter(dataframe["Schooling"], dataframe["Income_Comp_Of_Resources"])

# %% [markdown]
# We can infer that schooling and income composition are positively correlated between themselves and with life expectancy

# %%
plt.figure(figsize=(7,5))
plt.title("LifeExpectancy w.r.t Adult Mortality")
plt.xlabel("Adult Mortality",fontsize=12)
plt.ylabel("Life_Expectancy",fontsize=12)
plt.scatter(dataframe["Adult_Mortality"], dataframe["Life_Expectancy"])

# %%
plt.figure(figsize=(7,5))
plt.title("LifeExpectancy w.r.t GDP")
plt.xlabel("GDP",fontsize=12)
plt.ylabel("Life_Expectancy",fontsize=12)
plt.scatter(dataframe["GDP"], dataframe["Life_Expectancy"])

# %%
plt.figure(figsize=(12, 38))

plt.subplot(8,2,1)
plt.title("LifeExpectancy & GDP")
plt.scatter(dataframe["GDP"], dataframe["Life_Expectancy"])

plt.subplot(8,2,2)
plt.title("LifeExpectancy & Adult Mortality")
plt.scatter(dataframe["Adult_Mortality"], dataframe["Life_Expectancy"])

plt.subplot(8,2,3)
plt.title("LifeExpectancy & Schooling")
plt.scatter(dataframe["Schooling"], dataframe["Life_Expectancy"])

plt.subplot(8,2,4)
plt.title("LifeExpectancy & Income_Comp_Of_Resources")
plt.scatter(dataframe["Income_Comp_Of_Resources"], dataframe["Life_Expectancy"])

# %% [markdown]
# The four features shown above plus the status of the country will be used for building the machine learning model

# %% [markdown]
# ## Data loaders
# Now I will prepare the designated column into the data that will be used in the machine learning model

# %% [markdown]
# categorical_cols = ['Status']: This line creates a list categorical_cols containing the name of the column 'Status'. It suggests that the 'Status' column contains categorical data.
#
# TARGET_COLUMN = ['Life_Expectancy']: This line creates a list TARGET_COLUMN containing the name of the target column, which is 'Life_Expectancy'. It indicates that 'Life_Expectancy' is the variable we want to predict or analyze.

# %%
# label the designated data
# num_rows = dataframe.index.size
# categorical_cols = ['Status']
# TARGET_COLUMN = ['Life_Expectancy']
# Preparing the dataframe for futher machine learning analysis
inputs = ['Status', 'GDP', 'Adult_Mortality', 'Schooling', 'Income_Comp_Of_Resources', 'Life_Expectancy']
dataframe_df = dataframe[inputs]
dataframe_df.head()
# Out:
#        Status         GDP  Adult_Mortality  Schooling  \
# 0  Developing  584.259210            263.0       10.1
# 1  Developing  612.696514            271.0       10.0
# 2  Developing  631.744976            268.0        9.9
# 3  Developing  669.959000            272.0        9.8
# 4  Developing   63.537231            275.0        9.5
#
#    Income_Comp_Of_Resources  Life_Expectancy
# 0                     0.479             65.0
# 1                     0.476             59.9
# 2                     0.470             59.9
# 3                     0.463             59.5
# 4                     0.454             59.2

# %% [markdown]
# The drop_first=True argument is used to drop one of the dummy columns to avoid multicollinearity. As a result, you get a DataFrame with a single "Status" column containing binary values.

# %%
# Convert categorical data to numeric with `pd.get_dummies`
numeric_df = pd.get_dummies(dataframe_df, drop_first=True)
numeric_df.rename(columns={'Status_Developing': 'Status'}, inplace=True)
numeric_df.sample(20)
# Out:
#                GDP  Adult_Mortality  Schooling  Income_Comp_Of_Resources  \
# 1023     39.484473             31.0        7.6                     0.484
# 2567     17.815972            194.0        9.7                     0.535
# 1188   1452.195373            187.0       11.5                     0.599
# 1960  12593.737400            119.0       13.0                     0.780
# 1799   5749.447520            232.0       11.5                     0.619
# 2250    152.443873            192.0        9.1                     0.483
# 1657    146.838510            215.0        7.1                     0.476
# 1805   3881.295350            431.0       11.4                     0.570
# 393    4513.136280            161.0       13.5                     0.750
# 1841  35245.164700              8.0       16.5                     0.881
# 1954    563.594342            185.0        5.6                     0.465
# 62      526.168743             44.0        5.1                     0.391
# 397     287.534843            157.0       12.9                     0.723
# 2404   4863.516880            497.0       12.9                     0.611
# 1785    987.736583             29.0        8.8                     0.515
# 2622    487.923891            323.0       11.0                     0.449
# 1950     95.432793            178.0        6.7                     0.505
# 1471   5436.595223             17.0       15.2                     0.000
# 1786    741.777116            211.0        8.5                     0.504
# 2475   9484.568980            179.0       12.7                     0.719
#
#       Life_Expectancy  Status
# 1023             57.6       1
# 2567             64.0       1
# 1188             67.6       1
# 1960             77.6       1
# 1799             65.8       1
# 2250             66.4       1
# 1657             61.7       1
# 1805             57.0       1
# 393              72.2       0
# 1841             78.7       0
# 1954             63.5       1
# 62               45.7       1
# 397              71.8       0
# 2404             53.7       1
# 1785             65.4       1
# 2622             57.4       1
# 1950             64.4       1
# 1471             73.2       1
# 1786             65.2       1
# 2475             71.2       1

# %% [markdown]
# Note: numeric_df represents the actual status labels (Developing: 1, Developed: 0) for the samples in the dataset.

# %%
# Split our preprocessed data into our features and target arrays
y = numeric_df["Status"].values.reshape(-1,1)
X = numeric_df.drop(["Status"],1) 

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state = 42)
# Out:
# C:\Users\panka\AppData\Local\Temp\ipykernel_20736\4188055797.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X = numeric_df.drop(["Status"],1)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# Compile, Train and Evaluate the Model

# %% [markdown]
# For this neural network model, I chose four hidden layers with 80,30, 10, and 5 neurons respectively. This combination of neurons and layers produced the best results in terms of accuracy and loss. For the activation functions, I chose ReLU for the first hidden layer to introduce non-linearity in the model and improve its performance. I selected sigmoid for the second, tanh for the third and soft-max for the fourth to increase accuracy of the model. For the final output layer, I used sigmoid activation function to ensure the output is between 0 and 1, which is needed for binary classification.

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train.values[0])

hidden_nodes_layer1 = 80
hidden_nodes_layer2 = 30
hidden_nodes_layer3 = 10
hidden_nodes_layer4 = 5

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="sigmoid"))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="tanh"))

# Fourth hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer4, activation="softmax"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                480
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 10)                310
#
#  dense_3 (Dense)             (None, 5)                 55
#
#  dense_4 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 3281 (12.82 KB)
# Trainable params: 3281 (12.82 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Create directory if it does not exist
if not os.path.exists('C:/Users/panka/OneDrive/Desktop/Class Folder/Github/Machine-learning-projects/Age prediction work/models/model_1'):
    os.makedirs('C:/Users/panka/OneDrive/Desktop/Class Folder/Github/Machine-learning-projects/Age prediction work/models/model_1')

# Define the checkpoint path
checkpoint_path = "C:/Users/panka/OneDrive/Desktop/Class Folder/Github/Machine-learning-projects/Age prediction work/models/model_1/weights.{epoch:02d}.hdf5"

# Create the checkpoint callback
checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    verbose=1,
    save_weights_only=True,
    save_freq='epoch',
    period = 5
)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# Train the model
nn.fit(X_train_scaled, y_train, epochs=100,callbacks=[checkpoint_callback])
# Out:
# Epoch 1/100
# 47/47 [==============================] - 1s 1ms/step - loss: 0.5416 - accuracy: 0.8483
# Epoch 2/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4684 - accuracy: 0.8483
# Epoch 3/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4206 - accuracy: 0.8564
# Epoch 4/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3845 - accuracy: 0.9007
# Epoch 5/100
# 35/47 [=====================>........] - ETA: 0s - loss: 0.3712 - accuracy: 0.8973
# Epoch 5: saving model to C:/Users/panka/OneDrive/Desktop/Class Folder/Github/Machine-learning-projects/Age prediction work/models/model_1\weights.05.hdf5
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3634 - accuracy: 0.9040
# Epoch 6/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3464 - accuracy: 0.9114
# Epoch 7/100
# 47/47 [==============================] - 0s 958us/step - loss: 0.3335 - accuracy: 0.9121
# Epoch 8/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3208 - accuracy: 0.9128
# Epoch 9/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3090 - accuracy: 0.9161
# Epoch 10/100
#  1/47 [..............................] - ETA: 0s - loss: 0.3563 - accuracy: 0.9375
# Epoch 10: saving model to C:/Users/panka/OneDrive/Desktop/Class Folder/Github/Machine-learning-projects/Age prediction work/models/model_1\weights.10.hdf5
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3009 - accuracy: 0.9161
# Epoch 11/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.2927 - accuracy: 0.9148
# Epoch 12/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.2836 - accuracy: 0.9208
# Epoch 13/100
# 47/47 [==============================] - 0s 992us/step - loss: 0.2774 - accuracy: 0.9174
# Epoch 14/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.2709 - accuracy: 0.9208
# Epoch 15/100
# 47/47 [==============================] - ETA: 0s - loss: 0.2649 - accuracy: 0.9215
# Epoch 15: saving model to C:/Users/panka/OneDrive/Desktop/Class Folder/Github/Machine-learning-projects/Age prediction work/models/model_1\weights.15.hdf5
# 47/47 [==============================] - 0s 1ms/step - loss: 0.2649 - accuracy: 0.9215
# Epoch 16/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.2588 - accuracy: 0.9215
# Epoch 17/100
# 47/47 [==============================] - 0s 982us/step - loss: 0.2551 - accuracy: 0.9215
# Epoch 18/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.2535 - accuracy: 0.9174
# Epoch 19/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.2457 - accuracy: 0.9248
# Epoch 20/100
#  1/47 [..............................] - ETA: 0s - loss: 0.1787 - accuracy: 0.9688
# Epoch 20: saving model to C:/Users/panka/OneDrive/Desktop/Class Folder/Github/Machine-learning-projects/Age prediction work/models/model_1\weights.20.hdf5
# 47/47 [==============================] - 0s 1ms/step - loss: 0.2429 - accuracy: 0.9242
# Epoch 21/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.2402 - accuracy: 0.9208
# Epoch 22/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.2342 - accuracy: 0.9242
# Epoch 23/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.2310 - accuracy: 0.9262
# Epoch 24/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.2282 - accuracy: 0.9228
# Epoch 25/100
#  1/47 [..............................] - ETA: 0s - loss: 0.2401 - accuracy: 0.9375
# Epoch 25: saving model to C:/Users/panka/OneDrive/Desktop/Class Folder/Github/Machine-learning-projects/Age prediction work/models/model_1\weights.25.hdf5
# 47/47 [==============================] - 0s 1ms/step - loss: 0.2246 - accuracy: 0.9248
# Epoch 26/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.2217 - accuracy: 0.9262
# Epoch 27/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.2189 - accuracy: 0.9262
# Epoch 28/100
# 47/47 [==============================] - 0s 997us/step - loss: 0.2176 - accuracy: 0.9262
# Epoch 29/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.2148 - accuracy: 0.9282
# Epoch 30/100
#  1/47 [..............................] - ETA: 0s - loss: 0.2360 - accuracy: 0.9062
# Epoch 30: saving model to C:/Users/panka/OneDrive/Desktop/Class Folder/Github/Machine-learning-projects/Age prediction work/models/model_1\weights.30.hdf5
# 47/47 [==============================] - 0s 1ms/step - loss: 0.2128 - accuracy: 0.9255
# Epoch 31/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.2113 - accuracy: 0.9268
# Epoch 32/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.2095 - accuracy: 0.9262
# Epoch 33/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.2069 - accuracy: 0.9275
# Epoch 34/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.2056 - accuracy: 0.9242
# Epoch 35/100
# 42/47 [=========================>....] - ETA: 0s - loss: 0.2024 - accuracy: 0.9286
# Epoch 35: saving model to C:/Users/panka/OneDrive/Desktop/Class Folder/Github/Machine-learning-projects/Age prediction work/models/model_1\weights.35.hdf5
# 47/47 [==============================] - 0s 2ms/step - loss: 0.2018 - accuracy: 0.9282
# Epoch 36/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.2006 - accuracy: 0.9282
# Epoch 37/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1985 - accuracy: 0.9302
# Epoch 38/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1975 - accuracy: 0.9295
# Epoch 39/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1977 - accuracy: 0.9295
# Epoch 40/100
#  1/47 [..............................] - ETA: 0s - loss: 0.2758 - accuracy: 0.8750
# Epoch 40: saving model to C:/Users/panka/OneDrive/Desktop/Class Folder/Github/Machine-learning-projects/Age prediction work/models/model_1\weights.40.hdf5
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1946 - accuracy: 0.9309
# Epoch 41/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1944 - accuracy: 0.9282
# Epoch 42/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1959 - accuracy: 0.9282
# Epoch 43/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1913 - accuracy: 0.9302
# Epoch 44/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1888 - accuracy: 0.9309
# Epoch 45/100
# 47/47 [==============================] - ETA: 0s - loss: 0.1892 - accuracy: 0.9315
# Epoch 45: saving model to C:/Users/panka/OneDrive/Desktop/Class Folder/Github/Machine-learning-projects/Age prediction work/models/model_1\weights.45.hdf5
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1892 - accuracy: 0.9315
# Epoch 46/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1894 - accuracy: 0.9309
# Epoch 47/100
# 47/47 [==============================] - 0s 945us/step - loss: 0.1885 - accuracy: 0.9302
# Epoch 48/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1881 - accuracy: 0.9315
# Epoch 49/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1844 - accuracy: 0.9336
# Epoch 50/100
# 45/47 [===========================>..] - ETA: 0s - loss: 0.1859 - accuracy: 0.9326
# Epoch 50: saving model to C:/Users/panka/OneDrive/Desktop/Class Folder/Github/Machine-learning-projects/Age prediction work/models/model_1\weights.50.hdf5
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1827 - accuracy: 0.9342
# Epoch 51/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1814 - accuracy: 0.9349
# Epoch 52/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1837 - accuracy: 0.9302
# Epoch 53/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1818 - accuracy: 0.9329
# Epoch 54/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1802 - accuracy: 0.9349
# Epoch 55/100
#  1/47 [..............................] - ETA: 0s - loss: 0.3287 - accuracy: 0.9062
# Epoch 55: saving model to C:/Users/panka/OneDrive/Desktop/Class Folder/Github/Machine-learning-projects/Age prediction work/models/model_1\weights.55.hdf5
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1826 - accuracy: 0.9315
# Epoch 56/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1799 - accuracy: 0.9342
# Epoch 57/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1780 - accuracy: 0.9369
# Epoch 58/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1785 - accuracy: 0.9349
# Epoch 59/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1760 - accuracy: 0.9376
# Epoch 60/100
#  1/47 [..............................] - ETA: 0s - loss: 0.1203 - accuracy: 0.9688
# Epoch 60: saving model to C:/Users/panka/OneDrive/Desktop/Class Folder/Github/Machine-learning-projects/Age prediction work/models/model_1\weights.60.hdf5
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1762 - accuracy: 0.9336
# Epoch 61/100
# 47/47 [==============================] - 0s 997us/step - loss: 0.1775 - accuracy: 0.9329
# Epoch 62/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1756 - accuracy: 0.9322
# Epoch 63/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1755 - accuracy: 0.9329
# Epoch 64/100
# 47/47 [==============================] - 0s 982us/step - loss: 0.1778 - accuracy: 0.9309
# Epoch 65/100
#  1/47 [..............................] - ETA: 0s - loss: 0.3240 - accuracy: 0.8438
# Epoch 65: saving model to C:/Users/panka/OneDrive/Desktop/Class Folder/Github/Machine-learning-projects/Age prediction work/models/model_1\weights.65.hdf5
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1725 - accuracy: 0.9362
# Epoch 66/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1728 - accuracy: 0.9369
# Epoch 67/100
# 47/47 [==============================] - 0s 985us/step - loss: 0.1724 - accuracy: 0.9376
# Epoch 68/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1731 - accuracy: 0.9362
# Epoch 69/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1751 - accuracy: 0.9329
# Epoch 70/100
#  1/47 [..............................] - ETA: 0s - loss: 0.3527 - accuracy: 0.9062
# Epoch 70: saving model to C:/Users/panka/OneDrive/Desktop/Class Folder/Github/Machine-learning-projects/Age prediction work/models/model_1\weights.70.hdf5
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1845 - accuracy: 0.9282
# Epoch 71/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1741 - accuracy: 0.9336
# Epoch 72/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1702 - accuracy: 0.9356
# Epoch 73/100
# 47/47 [==============================] - 0s 990us/step - loss: 0.1711 - accuracy: 0.9376
# Epoch 74/100
# 47/47 [==============================] - 0s 965us/step - loss: 0.1687 - accuracy: 0.9389
# Epoch 75/100
#  1/47 [..............................] - ETA: 0s - loss: 0.0651 - accuracy: 1.0000
# Epoch 75: saving model to C:/Users/panka/OneDrive/Desktop/Class Folder/Github/Machine-learning-projects/Age prediction work/models/model_1\weights.75.hdf5
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1706 - accuracy: 0.9383
# Epoch 76/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1714 - accuracy: 0.9349
# Epoch 77/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1729 - accuracy: 0.9349
# Epoch 78/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1701 - accuracy: 0.9349
# Epoch 79/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1685 - accuracy: 0.9376
# Epoch 80/100
# 43/47 [==========================>...] - ETA: 0s - loss: 0.1650 - accuracy: 0.9360
# Epoch 80: saving model to C:/Users/panka/OneDrive/Desktop/Class Folder/Github/Machine-learning-projects/Age prediction work/models/model_1\weights.80.hdf5
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1685 - accuracy: 0.9342
# Epoch 81/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1701 - accuracy: 0.9389
# Epoch 82/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1654 - accuracy: 0.9389
# Epoch 83/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.1667 - accuracy: 0.9403
# Epoch 84/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.1665 - accuracy: 0.9383
# Epoch 85/100
# 29/47 [=================>............] - ETA: 0s - loss: 0.1711 - accuracy: 0.9300
# Epoch 85: saving model to C:/Users/panka/OneDrive/Desktop/Class Folder/Github/Machine-learning-projects/Age prediction work/models/model_1\weights.85.hdf5
# 47/47 [==============================] - 0s 2ms/step - loss: 0.1718 - accuracy: 0.9315
# Epoch 86/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1656 - accuracy: 0.9389
# Epoch 87/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1625 - accuracy: 0.9389
# Epoch 88/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1629 - accuracy: 0.9403
# Epoch 89/100
# 47/47 [==============================] - 0s 989us/step - loss: 0.1634 - accuracy: 0.9416
# Epoch 90/100
# 46/47 [============================>.] - ETA: 0s - loss: 0.1661 - accuracy: 0.9375
# Epoch 90: saving model to C:/Users/panka/OneDrive/Desktop/Class Folder/Github/Machine-learning-projects/Age prediction work/models/model_1\weights.90.hdf5
# 47/47 [==============================] - 0s 2ms/step - loss: 0.1662 - accuracy: 0.9369
# Epoch 91/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1606 - accuracy: 0.9423
# Epoch 92/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1631 - accuracy: 0.9403
# Epoch 93/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1600 - accuracy: 0.9409
# Epoch 94/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1611 - accuracy: 0.9396
# Epoch 95/100
#  1/47 [..............................] - ETA: 0s - loss: 0.0951 - accuracy: 0.9688
# Epoch 95: saving model to C:/Users/panka/OneDrive/Desktop/Class Folder/Github/Machine-learning-projects/Age prediction work/models/model_1\weights.95.hdf5
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1617 - accuracy: 0.9403
# Epoch 96/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1604 - accuracy: 0.9403
# Epoch 97/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1637 - accuracy: 0.9396
# Epoch 98/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1621 - accuracy: 0.9403
# Epoch 99/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.1578 - accuracy: 0.9430
# Epoch 100/100
# 44/47 [===========================>..] - ETA: 0s - loss: 0.1603 - accuracy: 0.9418
# Epoch 100: saving model to C:/Users/panka/OneDrive/Desktop/Class Folder/Github/Machine-learning-projects/Age prediction work/models/model_1\weights.100.hdf5
# 47/47 [==============================] - 0s 2ms/step - loss: 0.1586 - accuracy: 0.9430

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 16/16 - 0s - loss: 0.1705 - accuracy: 0.9215 - 109ms/epoch - 7ms/step
# Loss: 0.1705012172460556, Accuracy: 0.9215291738510132

# %%
# Export our model to HDF5 file
nn.save('C:/Users/panka/OneDrive/Desktop/Class Folder/Github/Machine-learning-projects/Age prediction work/models/model_1/Age_of_death_prediction.h5')
# Out:
# C:\Users\panka\anaconda3\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# I have developed a successful deep neural network model using TensorFlow and Keras to predict if an Age_of_death_predictions by WHO would be successful. Through several iterations for the optimal model, I am able to achieve a final accuracy score of 92.15%. This model could be a valuable tool for WHO in selecting the country as the developed or developing with the best chance of success.

# %% [markdown]
# Predictions

# %%
# Load the trained model
model = tf.keras.models.load_model('C:/Users/panka/OneDrive/Desktop/Class Folder/Github/Machine-learning-projects/Age prediction work/models/model_1/Age_of_death_prediction.h5')

# Create a new DataFrame with the same columns as the original data (excluding 'Status')
new_data = pd.DataFrame({
    'GDP': [4000, 1500, 10000],  # Add more values for other countries
    'Adult_Mortality': [200, 180, 50],
    'Schooling': [10, 7, 15],
    'Income_Comp_Of_Resources': [0.6, 0.4, 0.8],
    'Life_Expectancy': [70, 65, 80]
})

# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler on the training data
X_scaler = scaler.fit(X_train)

# Scale the new data using the same scaler
X_new_scaled = X_scaler.transform(new_data)

# Make predictions using the loaded model
predictions = model.predict(X_new_scaled)

# Assuming your model performs binary classification (0 or 1)
# You can round the predictions to obtain the predicted status (0 or 1)
predicted_status = np.round(predictions).flatten().astype(int)

# Create a DataFrame to show the predictions along with the original data
new_data_with_predictions = new_data.copy()
new_data_with_predictions['Predicted_Status'] = predicted_status

print(new_data_with_predictions)
# Out:
# 1/1 [==============================] - 0s 46ms/step
#      GDP  Adult_Mortality  Schooling  Income_Comp_Of_Resources  \
# 0   4000              200         10                       0.6
# 1   1500              180          7                       0.4
# 2  10000               50         15                       0.8
#
#    Life_Expectancy  Predicted_Status
# 0               70                 1
# 1               65                 1
# 2               80                 0

# %%
# Load the trained model
model = tf.keras.models.load_model('C:/Users/panka/OneDrive/Desktop/Class Folder/Github/Machine-learning-projects/Age prediction work/models/model_1/Age_of_death_prediction.h5')

# Assuming you have your original feature DataFrame 'X' used for training
# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler on the training data
X_scaler = scaler.fit(X)

# Scale the original data 'X' using the same scaler
X_scaled = X_scaler.transform(X)

# Make predictions using the loaded model
predictions = model.predict(X_scaled)

# Assuming your model performs binary classification (0 or 1)
# You can round the predictions to obtain the predicted status (0 or 1)
predicted_status = np.round(predictions).flatten().astype(int)

# # Add the predicted status as a new column to 'numeric_df'
# numeric_df['Predicted_Status'] = predicted_status

# print(numeric_df)

# Compare the predicted status with the original status
match = numeric_df['Predicted_Status'] == numeric_df['Status']

# Calculate accuracy
accuracy = match.mean() * 100
print(f"Accuracy: {accuracy:.2f}%")
# Out:
# 63/63 [==============================] - 0s 757us/step
# Accuracy: 93.76%

# %%
model_loss, model_accuracy = nn.evaluate(X_scaled,y,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 63/63 - 0s - loss: 0.1604 - accuracy: 0.9376 - 54ms/epoch - 858us/step
# Loss: 0.1604197919368744, Accuracy: 0.9375943541526794

# %% [markdown]
# In this code, we calculate the accuracy by comparing the predicted status column (Predicted_Status) with the original status column (Status). The match variable will contain a boolean array indicating whether the predicted status matches the original status for each sample. The mean of the match array will give us the accuracy, which is then printed as a percentage.

# %%
numeric_df['Country'] = dataframe['Country']
numeric_df.head()
# Out:
#           GDP  Adult_Mortality  Schooling  Income_Comp_Of_Resources  \
# 0  584.259210            263.0       10.1                     0.479
# 1  612.696514            271.0       10.0                     0.476
# 2  631.744976            268.0        9.9                     0.470
# 3  669.959000            272.0        9.8                     0.463
# 4   63.537231            275.0        9.5                     0.454
#
#    Life_Expectancy  Status  Predicted_Status      Country
# 0             65.0       1                 1  Afghanistan
# 1             59.9       1                 1  Afghanistan
# 2             59.9       1                 1  Afghanistan
# 3             59.5       1                 1  Afghanistan
# 4             59.2       1                 1  Afghanistan

# %%
# Plotting Country vs. Status and Predicted_Status using groupby
plt.figure(figsize=(8, 8))
status_mean = numeric_df.groupby('Country')['Status'].mean()
# predicted_status_mean = numeric_df.groupby('Country')['Predicted_Status'].mean()
status_mean.plot(kind='bar', color='blue', alpha=0.5, label='Status (Developing)')
# predicted_status_mean.plot(kind='bar', color='red', alpha=0.5, label='Predicted Status (Developing)')
plt.xlabel("Country", fontsize=12)
plt.ylabel("Percentage of Developing Status", fontsize=12)
plt.title("Country vs. Status and Predicted Status", fontsize=14)
plt.legend()
plt.xticks(rotation=45)
plt.show()
